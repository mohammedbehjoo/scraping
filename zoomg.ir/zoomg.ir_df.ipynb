# %%
import pandas as pd

# %%
df=pd.read_json("/home/mohammed/projects/coding/scraping/zoomg.ir/scrapy_zoomg/output.json")
df
# Out:
#                                                  title         author  \
# 0     گزارش تصویری زومجی از گیم نت تکاف | تجربه باز...    فراز پاشایی
# 1                                                 None           None
# 2     همه چیز درباره همستر کامبت + کد و دیلی کمبو ۶...  محمدحسین خلجی
# 3                                                 None           None
# 4     نتایج بنچمارک پردازنده های AMD Ryzen 9000 لو ...    یاشار ظروفی
# ..                                                 ...            ...
# 395                                               None           None
# 396          تاریخ عرضه Valorant برای کنسول‌ها فاش شد      علی نوروزی
# 397                                               None           None
# 398     زمان عرضه Modern Warfare 3 برای گیم پس لو رفت      علی نوروزی
# 399                                               None           None
#
#                  date                                            summery  \
# 0    20:59 1403/05/07  آیا مایل هستید با یک پی سی گیمینگ خیلی قوی به ...
# 1                None                                               None
# 2    20:46 1403/05/07  در این مطلب به بررسی همستر کامبت می‌پردازیم و ...
# 3                None                                               None
# 4    20:23 1403/05/07  افشاگران قبل از اعلام رسمی، نتایج بنچمارک‌های ...
# ..                ...                                                ...
# 395              None                                               None
# 396  09:19 1403/05/01  یکی از افشاگرهای سرشناس از زمان احتمالی انتشار...
# 397              None                                               None
# 398  09:09 1403/05/01  یکی از افشاگرهای خوش‌سابقه زمان راه‌یابی بازی ...
# 399              None                                               None
#
#                    categories  \
# 0      [ویدیو, اختصاصی زومجی]
# 1      [ویدیو, اختصاصی زومجی]
# 2                          []
# 3                          []
# 4             [شرکت ای ام دی]
# ..                        ...
# 395                        []
# 396  [پلی استیشن, ایکس‌ باکس]
# 397  [پلی استیشن, ایکس‌ باکس]
# 398    [ایکس‌ باکس, کامپیوتر]
# 399    [ایکس‌ باکس, کامپیوتر]
#
#                                                    url
# 0    https://www.zoomg.ir/game-articles/370261-tecc...
# 1                                                 None
# 2    https://www.zoomg.ir/learning/369147-everythin...
# 3                                                 None
# 4    https://www.zoomg.ir/hardware-news/370263-amd-...
# ..                                                 ...
# 395                                               None
# 396  https://www.zoomg.ir/game-news/370066-valorant...
# 397                                               None
# 398  https://www.zoomg.ir/game-news/370063-modern-w...
# 399                                               None
#
# [400 rows x 6 columns]

# %% [markdown]
# Number of Null values

# %%
df["title"].isnull().sum()
# Out:
# 200

# %% [markdown]
# Let's drop Null values

# %%
df.dropna(inplace=True)
df.describe()
# Out:
#                                                     title       author  \
# count                                                 200          200
# unique                                                192           25
# top      بازی Conscript برای کنسول ها و کامپیوتر منتشر...  یاشار ظروفی
# freq                                                    2           37
#
#                     date                                            summery  \
# count                200                                                200
# unique               192                                                192
# top     23:33 1403/05/02  بازی جدید Conscript در ژانر ترسناک و بقا با مح...
# freq                   2                                                  2
#
#        categories                                                url
# count         200                                                200
# unique         86                                                192
# top            []  https://www.zoomg.ir/game-news/370119-conscrip...
# freq           41                                                  2

# %%
df["title"]
# Out:
# 0       گزارش تصویری زومجی از گیم نت تکاف | تجربه باز...
# 2       همه چیز درباره همستر کامبت + کد و دیلی کمبو ۶...
# 4       نتایج بنچمارک پردازنده های AMD Ryzen 9000 لو ...
# 6       آپدیت جدید بازی No Rest for the Wicked منتشر شد
# 8       جوکر قرار نیست در فیلم Joker 2 تبدیل به یک جن...
#                              ...
# 390              مهران مدیری با گل یا پوچ به فیلیمو آمد
# 392                                سعید راد از دنیا رفت
# 394            بررسی گلکسی زد فلیپ ۶؛ جامانده‌ی بی‌خیال
# 396            تاریخ عرضه Valorant برای کنسول‌ها فاش شد
# 398       زمان عرضه Modern Warfare 3 برای گیم پس لو رفت
# Name: title, Length: 200, dtype: object
